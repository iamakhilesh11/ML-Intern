# %%
import pandas as pd
df= pd.read_csv('E:\Internship\Module 1\TSLA.csv')
df
# Out:
#              Date  Close Price  Open Price  High Price  Low Price  \
# 0    Oct 24, 2019       299.68      298.97      304.74     290.05
# 1    Oct 23, 2019       254.68      254.50      256.14     251.35
# 2    Oct 22, 2019       255.58      254.32      258.33     250.85
# 3    Oct 21, 2019       253.50      258.33      259.50     250.18
# 4    Oct 18, 2019       256.95      260.70      262.80     255.10
# ..            ...          ...         ...         ...        ...
# 498  Oct 31, 2017       331.53      320.23      331.95     320.18
# 499  Oct 30, 2017       320.08      319.18      323.78     317.25
# 500  Oct 27, 2017       320.87      319.75      324.59     316.66
# 501  Oct 26, 2017       326.17      327.78      330.23     323.20
# 502  Oct 25, 2017       325.84      336.70      337.50     323.56
#
#     Total Traded Quantity
# 0                  29.82M
# 1                  11.22M
# 2                   4.63M
# 3                   5.11M
# 4                   5.75M
# ...

# %%
dfObj=df.tail(90)
dfObj
# Out:
#              Date  Close Price  Open Price  High Price  Low Price  \
# 413  Mar 06, 2018       328.20      333.75      336.37     327.03
# 414  Mar 05, 2018       333.35      332.39      337.75     329.29
# 415  Mar 02, 2018       335.12      326.98      335.22     322.97
# 416  Mar 01, 2018       330.93      345.01      348.67     330.07
# 417  Feb 28, 2018       343.06      352.57      355.24     342.22
# ..            ...          ...         ...         ...        ...
# 498  Oct 31, 2017       331.53      320.23      331.95     320.18
# 499  Oct 30, 2017       320.08      319.18      323.78     317.25
# 500  Oct 27, 2017       320.87      319.75      324.59     316.66
# 501  Oct 26, 2017       326.17      327.78      330.23     323.20
# 502  Oct 25, 2017       325.84      336.70      337.50     323.56
#
#     Total Traded Quantity
# 413                 4.29M
# 414                 3.82M
# 415                 5.09M
# 416                 6.89M
# 417                 6.07M
# ...

# %%
maxValuesObj = dfObj.max()
print('Maximum value in each column : ')
print(maxValuesObj)
# Out:
# Maximum value in each column :
# Date                     Oct 31, 2017
# Close Price                    357.42
# Open Price                        360
# High Price                      360.5
# Low Price                      352.36
# Total Traded Quantity           9.95M
# dtype: object

# %%
# Get maximum value of a single column 'Close Price'
maxValue = dfObj['Close Price'].max()
print("Maximum value in column 'Close Price': " , maxValue)
# Out:
# Maximum value in column 'Close Price':  357.42

# %%
minValuesObj = dfObj.min()
print('Minimum value in each column : ')
print(minValuesObj)
# Out:
# Minimum value in each column :
# Date                     Dec 01, 2017
# Close Price                    299.26
# Open Price                      299.5
# High Price                     304.46
# Low Price                      292.63
# Total Traded Quantity          10.31M
# dtype: object

# %%
# Get minimum value of a single column 'Close Price'
minValue = dfObj['Close Price'].min()
print("Minimum value in column 'Close Price': " , minValue)
# Out:
# Minimum value in column 'Close Price':  299.26

# %%
meanValuesObj = dfObj.mean()
print('Mean value in each column : ')
print(meanValuesObj)
# Out:
# Mean value in each column :
# Close Price    326.810556
# Open Price     326.697000
# High Price     331.813667
# Low Price      321.638000
# dtype: float64

# %%
# Get mean value of a single column 'Close Price'
meanValue = dfObj['Close Price'].mean()
print("Mean value in column 'Close Price': " , meanValue)
# Out:
# Mean value in column 'Close Price':  326.81055555555554

# %%
dataTypes=df.dtypes
dataTypes
# Out:
# Date                      object
# Close Price              float64
# Open Price               float64
# High Price               float64
# Low Price                float64
# Total Traded Quantity     object
# dtype: object

# %%
# change date from object to datetime64[ns] format
df['Date'] = pd.to_datetime(df.Date)
print (df)
# Out:
#           Date  Close Price  Open Price  High Price  Low Price  \
# 0   2019-10-24       299.68      298.97      304.74     290.05
# 1   2019-10-23       254.68      254.50      256.14     251.35
# 2   2019-10-22       255.58      254.32      258.33     250.85
# 3   2019-10-21       253.50      258.33      259.50     250.18
# 4   2019-10-18       256.95      260.70      262.80     255.10
# ..         ...          ...         ...         ...        ...
# 498 2017-10-31       331.53      320.23      331.95     320.18
# 499 2017-10-30       320.08      319.18      323.78     317.25
# 500 2017-10-27       320.87      319.75      324.59     316.66
# 501 2017-10-26       326.17      327.78      330.23     323.20
# 502 2017-10-25       325.84      336.70      337.50     323.56
#
#     Total Traded Quantity
# 0                  29.82M
# 1                  11.22M
# 2                   4.63M
# 3                   5.11M
# 4                   5.75M
# ..                    ...
# ...

# %%
df.dtypes
# Out:
# Date                     datetime64[ns]
# Close Price                     float64
# Open Price                      float64
# High Price                      float64
# Low Price                       float64
# Total Traded Quantity            object
# dtype: object

# %%
minDate = df['Date'].min()
maxDate = df['Date'].max()
print("Subtraction of min from max in 'Date': " , maxDate-minDate)
# Out:
# Subtraction of min from max in 'Date':  729 days 00:00:00

# %%
# Adding Month and Year coloumn
df['Year'] = pd.DatetimeIndex(df['Date']).year
df['Month'] = pd.DatetimeIndex(df['Date']).month
df.head()
# Out:
#         Date  Close Price  Open Price  High Price  Low Price  \
# 0 2019-10-24       299.68      298.97      304.74     290.05
# 1 2019-10-23       254.68      254.50      256.14     251.35
# 2 2019-10-22       255.58      254.32      258.33     250.85
# 3 2019-10-21       253.50      258.33      259.50     250.18
# 4 2019-10-18       256.95      260.70      262.80     255.10
#
#   Total Traded Quantity  Year  Month
# 0                29.82M  2019     10
# 1                11.22M  2019     10
# 2                 4.63M  2019     10
# 3                 5.11M  2019     10
# 4                 5.75M  2019     10

# %%
groupByMonth = df.groupby(['Year','Month']).groups
groupByMonth
# Out:
# {(2017, 10): Int64Index([498, 499, 500, 501, 502], dtype='int64'),
#  (2017,
#   11): Int64Index([477, 478, 479, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489,
#              490, 491, 492, 493, 494, 495, 496, 497],
#             dtype='int64'),
#  (2017,
#   12): Int64Index([457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 468, 469,
#              470, 471, 472, 473, 474, 475, 476],
#             dtype='int64'),
#  (2018,
#   1): Int64Index([436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447, 448,
#              449, 450, 451, 452, 453, 454, 455, 456],
#             dtype='int64'),
#  (2018,
#   2): Int64Index([417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429,
#              430, 431, 432, 433, 434, 435],
#             dtype='int64'),
#  (2018,
#   3): Int64Index([396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408,
#              409, 410, 411, 412, 413, 414, 415, 416],
#             dtype='int64'),
#  (2018,
# ...

# %%
df.dtypes
# Out:
# Date                     datetime64[ns]
# Close Price                     float64
# Open Price                      float64
# High Price                      float64
# Low Price                       float64
# Total Traded Quantity            object
# Year                              int64
# Month                             int64
# dtype: object

# %%
df
# Out:
#           Date  Close Price  Open Price  High Price  Low Price  \
# 0   2019-10-24       299.68      298.97      304.74     290.05
# 1   2019-10-23       254.68      254.50      256.14     251.35
# 2   2019-10-22       255.58      254.32      258.33     250.85
# 3   2019-10-21       253.50      258.33      259.50     250.18
# 4   2019-10-18       256.95      260.70      262.80     255.10
# ..         ...          ...         ...         ...        ...
# 498 2017-10-31       331.53      320.23      331.95     320.18
# 499 2017-10-30       320.08      319.18      323.78     317.25
# 500 2017-10-27       320.87      319.75      324.59     316.66
# 501 2017-10-26       326.17      327.78      330.23     323.20
# 502 2017-10-25       325.84      336.70      337.50     323.56
#
#     Total Traded Quantity  Year  Month
# 0                  29.82M  2019     10
# 1                  11.22M  2019     10
# 2                   4.63M  2019     10
# 3                   5.11M  2019     10
# ...

# %%
df['Total Traded Quantity'] = df['Total Traded Quantity'].map(lambda x: x.rstrip('M'))
df
# Out:
#           Date  Close Price  Open Price  High Price  Low Price  \
# 0   2019-10-24       299.68      298.97      304.74     290.05
# 1   2019-10-23       254.68      254.50      256.14     251.35
# 2   2019-10-22       255.58      254.32      258.33     250.85
# 3   2019-10-21       253.50      258.33      259.50     250.18
# 4   2019-10-18       256.95      260.70      262.80     255.10
# ..         ...          ...         ...         ...        ...
# 498 2017-10-31       331.53      320.23      331.95     320.18
# 499 2017-10-30       320.08      319.18      323.78     317.25
# 500 2017-10-27       320.87      319.75      324.59     316.66
# 501 2017-10-26       326.17      327.78      330.23     323.20
# 502 2017-10-25       325.84      336.70      337.50     323.56
#
#     Total Traded Quantity  Year  Month
# 0                   29.82  2019     10
# 1                   11.22  2019     10
# 2                    4.63  2019     10
# 3                    5.11  2019     10
# ...

# %%
df.dtypes
# Out:
# Date                     datetime64[ns]
# Close Price                     float64
# Open Price                      float64
# High Price                      float64
# Low Price                       float64
# Total Traded Quantity            object
# Year                              int64
# Month                             int64
# dtype: object

# %%
df['Total Traded Quantity']=df['Total Traded Quantity'].astype(str).astype(float)

# %%
df.dtypes
# Out:
# Date                     datetime64[ns]
# Close Price                     float64
# Open Price                      float64
# High Price                      float64
# Low Price                       float64
# Total Traded Quantity           float64
# Year                              int64
# Month                             int64
# dtype: object

# %%
df['Total Traded Quantity']=df['Total Traded Quantity']*1000000
df
# Out:
#           Date  Close Price  Open Price  High Price  Low Price  \
# 0   2019-10-24       299.68      298.97      304.74     290.05
# 1   2019-10-23       254.68      254.50      256.14     251.35
# 2   2019-10-22       255.58      254.32      258.33     250.85
# 3   2019-10-21       253.50      258.33      259.50     250.18
# 4   2019-10-18       256.95      260.70      262.80     255.10
# ..         ...          ...         ...         ...        ...
# 498 2017-10-31       331.53      320.23      331.95     320.18
# 499 2017-10-30       320.08      319.18      323.78     317.25
# 500 2017-10-27       320.87      319.75      324.59     316.66
# 501 2017-10-26       326.17      327.78      330.23     323.20
# 502 2017-10-25       325.84      336.70      337.50     323.56
#
#      Total Traded Quantity  Year  Month
# 0               29820000.0  2019     10
# 1               11220000.0  2019     10
# 2                4630000.0  2019     10
# 3                5110000.0  2019     10
# ...

# %%
VWAP = sum(df['Close Price']*df['Total Traded Quantity'])/sum(df['Total Traded Quantity'])
VWAP
# Out:
# 287.99058289164367

# %%
# for last 1 week
Ndays=df.tail(5)
meanvalue1= Ndays['Close Price'].mean()
print("Mean of Close price for last 1 week': " , meanvalue1)

# for last 2 week
Ndays=df.tail(10)
meanvalue2= Ndays['Close Price'].mean()
print("Mean of Close price for last 2 week': " , meanvalue2)

# for last 1 month
Ndays=df.tail(20)
meanvalue3= Ndays['Close Price'].mean()
print("Mean of Close price for last 1 month': " , meanvalue3)

# for last 3 month
Ndays=df.tail(60)
meanvalue4= Ndays['Close Price'].mean()
print("Mean of Close price for last 3 month': " , meanvalue4)

# for last 6 month
Ndays=df.tail(120)
meanvalue5= Ndays['Close Price'].mean()
print("Mean of Close price for last 6 months': " , meanvalue5)

# for last 1 year
Ndays=df.tail(240)
meanvalue6= Ndays['Close Price'].mean()
print("Mean of Close price for last 1 year': " , meanvalue6)
# Out:
# Mean of Close price for last 1 week':  324.89799999999997
# Mean of Close price for last 2 week':  315.975
# Mean of Close price for last 1 month':  312.981
# Mean of Close price for last 3 month':  321.2793333333332
# Mean of Close price for last 6 months':  320.7910833333333
# Mean of Close price for last 1 year':  315.05687499999993

# %%
value1=df['Close Price'].iloc[-1]
value2=df['Close Price'].iloc[-2]
profitlossperc= (value1 -value2) / value1
profitlossperc1  = profitlossperc * 100

# %%
print("Loss': " , profitlossperc1, "%")
# Out:
# Loss':  -0.10127670022097991 %

# %%
df['Day_Perc_Change']=df['Close Price'].pct_change()

# %%
df
# Out:
#           Date  Close Price  Open Price  High Price  Low Price  \
# 0   2019-10-24       299.68      298.97      304.74     290.05
# 1   2019-10-23       254.68      254.50      256.14     251.35
# 2   2019-10-22       255.58      254.32      258.33     250.85
# 3   2019-10-21       253.50      258.33      259.50     250.18
# 4   2019-10-18       256.95      260.70      262.80     255.10
# ..         ...          ...         ...         ...        ...
# 498 2017-10-31       331.53      320.23      331.95     320.18
# 499 2017-10-30       320.08      319.18      323.78     317.25
# 500 2017-10-27       320.87      319.75      324.59     316.66
# 501 2017-10-26       326.17      327.78      330.23     323.20
# 502 2017-10-25       325.84      336.70      337.50     323.56
#
#      Total Traded Quantity  Year  Month  Day_Perc_Change
# 0               29820000.0  2019     10              NaN
# 1               11220000.0  2019     10        -0.150160
# ...

# %%
df["Day_Perc_Change"] = df["Day_Perc_Change"].fillna(0)
df

# %%
def trend(Day_Perc_Change):       
        if -0.5 <= df['Day_Perc_Change'] <=  0.5: return 'Slight'
        if  0.5 <= df['Day_Perc_Change'] <=  1:   return 'Slight positive'
        if -0.5 >= df['Day_Perc_Change'] >= -1:   return 'Slight negative'
        if  1   <= df['Day_Perc_Change'] <=  3:   return 'Positive'
        if -1   >= df['Day_Perc_Change'] >= -3:   return 'Negative'
        if  3   <= df['Day_Perc_Change'] <=  7:   return 'Among top gainers'
        if -3   >= df['Day_Perc_Change'] >= -7:   return 'Among top losers'
        if         df['Day_Perc_Change'] >   7:   return 'Bull run'
        if         df['Day_Perc_Change'] <  -7:   return 'Bear drop'

# %%
df['Trend'] = trend

# %%
df
# Out:
#           Date  Close Price  Open Price  High Price  Low Price  \
# 0   2019-10-24       299.68      298.97      304.74     290.05
# 1   2019-10-23       254.68      254.50      256.14     251.35
# 2   2019-10-22       255.58      254.32      258.33     250.85
# 3   2019-10-21       253.50      258.33      259.50     250.18
# 4   2019-10-18       256.95      260.70      262.80     255.10
# ..         ...          ...         ...         ...        ...
# 498 2017-10-31       331.53      320.23      331.95     320.18
# 499 2017-10-30       320.08      319.18      323.78     317.25
# 500 2017-10-27       320.87      319.75      324.59     316.66
# 501 2017-10-26       326.17      327.78      330.23     323.20
# 502 2017-10-25       325.84      336.70      337.50     323.56
#
#      Total Traded Quantity  Year  Month  Day_Perc_Change  \
# 0               29820000.0  2019     10              NaN
# 1               11220000.0  2019     10        -0.150160
# ...

# %%
df.to_csv (r'E:\Internship\Module 1\week2.csv', index = False, header=True)
